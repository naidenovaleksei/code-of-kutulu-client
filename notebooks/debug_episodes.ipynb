# %%
import torch
import numpy as np
import json
# import scipy.special as sp

# import pickle as pkl
# import zlib
# import base64

# %%
import sys
sys.path.append('/home/kutulu/projects/code-of-kutulu-client')

# %%
# from src.envs.agents.reinforce_agent import REINFORCEAgent
# from src.envs.agents.dqn_agent_ext import DQNAgentExt
# from src.envs.agents.dqn_agent import DQNAgent
from src.game.template import EXTENDED_KUTULU_ACTIONS, MAX_ENTITY_COUNT_BY_KIND
from src.envs.kutulu_observer import viz_observation, VIZ_MAP

import numpy as np

# %%
# !ls -lh test.pkl
# Out:
# -rw-rw-r-- 1 kutulu kutulu 11M Jun  9 19:43 test.pkl

# %%
import pickle as pkl
with open("test.pkl", "rb") as f:
    episode_buffer = pkl.load(f)

# %%
def print_exp(state):
    lines = [['.'] * 7 for i in range(7)]
    lines[3][3] = '0'
    for e in state:
        if abs(e['rel_x']) <= 3 and abs(e['rel_y']) <= 3:
            lines[3 + e['rel_y']][3 + e['rel_x']] = VIZ_MAP[e['kind']]
            print(e)
    for l in lines:
        print(''.join(l))

# %%
len(episode_buffer.buffer)
# Out:
# 5220

# %%
episode = episode_buffer.buffer[np.random.randint(len(episode_buffer.buffer))]

# %%
viz_observation(episode.observation, episode.action)
# Out:
# ###############
# #.............#
# #.#.#.#.#.#.#.#
# #..WW....W.w..#
# #.#.#.#.#.#.#.#
# #.........PR^.#
# #.#.#.#.#.#.#.#
# #.........1...#
# #.#.#.#.#.#.#.#
# #..w..R....w..#
# #.#.#.#.#.#.#.#
# #.............#
# ###############

# %%
from src.game.template import REL_POSITIONS

# %%
observation, action = episode.observation, episode.action

# %%
lines = observation['info']['lines']
entities = observation['obs']['entities']
player_id = observation['player_id']

curr_map = [list(line) for line in lines]
for e in entities:
    if e['id'] == player_id:
        agent_pos = (e['x'], e['y'])
        curr_map[e['y']][e['x']] = 'A'
    elif e['kind'] == 'EXPLORER':
        curr_map[e['y']][e['x']] = str(e['id'])
    else:
        curr_map[e['y']][e['x']] = VIZ_MAP[e['kind']]
if action is not None and action < len(REL_POSITIONS):
    rel_pos = REL_POSITIONS[action]
    x = agent_pos[0] + rel_pos[0]
    y = agent_pos[1] + rel_pos[1]
    curr_map[y][x] = '^'
for line in curr_map:
    print(''.join(line))
print()
# Out:
# ###############
# #.............#
# #.#.#.#.#.#.#.#
# #..WW....W.w..#
# #.#.#.#.#.#.#.#
# #.........PR^.#
# #.#.#.#.#.#.#.#
# #.........1...#
# #.#.#.#.#.#.#.#
# #..w..R....w..#
# #.#.#.#.#.#.#.#
# #.............#
# ###############

# %%
lines = observation['info']['lines']
curr_map = [list(line) for line in lines]
for e in entities:
    if e['id'] == player_id:
        agent_pos = (e['x'], e['y'])

# %%
agent_pos
# Out:
# (11, 5)

# %%
state = episode.state

# %%
size = 5

# %%
curr_map = [['#'] * int(size * 2 + 1) for i in range(int(size * 2 + 1))]
for rel_x in range(-size, size + 1):
    for rel_y in range(-size, size + 1):
        y = agent_pos[1] + rel_y
        x = agent_pos[0] + rel_x
        if 0 <= y and y < len(lines) and 0 <= x and x < len(lines[0]):
            curr_map[size + rel_y][size + rel_x] = lines[y][x]
curr_map[size][size] = 'A'
for e in state:
    rel_x = max(min(e['rel_x'], size), -size)
    rel_y = max(min(e['rel_y'], size), -size)
    if abs(rel_x) <= size and abs(rel_y) <= size:
        curr_map[size + rel_y][size + rel_x] = VIZ_MAP[e['kind']]
        print(e)
for l in curr_map:
    print(''.join(l))
# Out:
# {'kind': 'EXPLORER', 'param0': 207, 'param1': 1, 'param2': 0, 'rel_x': -1, 'rel_y': 0, 'dist': 1, 'dir': (3,), 'raw_dist': 1, 'on_los': True}
# {'kind': 'EXPLORER', 'param0': 147, 'param1': 0, 'param2': 0, 'rel_x': -1, 'rel_y': 2, 'dist': 3, 'dir': (2,), 'raw_dist': 3, 'on_los': False}
# {'kind': 'EXPLORER', 'param0': 150, 'param1': 0, 'param2': 0, 'rel_x': -5, 'rel_y': 4, 'dist': 9, 'dir': (2, 3), 'raw_dist': 9, 'on_los': False}
# {'kind': 'SLASHER', 'param0': 1, 'param1': 4, 'param2': -1, 'rel_x': 1, 'rel_y': 0, 'dist': 1, 'dir': (1,), 'raw_dist': 1, 'on_los': True}
# {'kind': 'WANDERER', 'param0': 28, 'param1': 1, 'param2': 0, 'rel_x': -2, 'rel_y': -2, 'dist': 4, 'dir': (0, 3), 'raw_dist': 4, 'on_los': False}
# {'kind': 'SLASHER', 'param0': 6, 'param1': 4, 'param2': -1, 'rel_x': -5, 'rel_y': 4, 'dist': 9, 'dir': (2, 3), 'raw_dist': 9, 'on_los': False}
# {'kind': 'WANDERER', 'param0': 33, 'param1': 1, 'param2': 3, 'rel_x': -7, 'rel_y': -2, 'dist': 9, 'dir': (0, 3), 'raw_dist': 9, 'on_los': False}
# {'kind': 'SLASHER', 'param0': 4, 'param1': 0, 'param2': 2, 'rel_x': 0, 'rel_y': 0, 'dist': 0, 'dir': (4,), 'raw_dist': 0, 'on_los': True}
# {'kind': 'WANDERER', 'param0': 4, 'param1': 0, 'param2': -1, 'rel_x': -8, 'rel_y': -2, 'dist': 10, 'dir': (0, 3), 'raw_dist': 10, 'on_los': False}
# {'kind': 'EFFECT_PLAN', 'param0': 4, 'param1': 0, 'param2': -1, 'rel_x': -1, 'rel_y': 0, 'dist': 1, 'dir': (3,), 'raw_dist': 1, 'on_los': True}
# ###########
# ........###
# #.#.#.#.###
# W..W.w..###
# #.#.#.#.###
# ....PRR.###
# #.#.#.#.###
# ....E...###
# #.#.#.#.###
# R....w..###
# #.#.#.#.###

# %%
MAP_MAP = {
    '#': 0,
    '.': 1,
    'w': 1,
    's': 1,
    'S': 1,
    'U': 2,
}

# %%
FEATURE_ENTITY_DICT = {
    'EXPLORER': ['param0', 'param1', 'param2'],
    'WANDERER': ['param0', 'param1'],
    'SLASHER': ['param0', 'param1'],
    'EFFECT_PLAN': ['param0'],
    'EFFECT_LIGHT': ['param0'],
    'EFFECT_SHELTER': ['param0'],
    'EFFECT_YELL': ['param0']
}

# %%
data = []

# %%
lines

# %%
curr_map = [[MAP_MAP['#']] * int(size * 2 + 1) for i in range(int(size * 2 + 1))]
for rel_x in range(-size, size + 1):
    for rel_y in range(-size, size + 1):
        y = agent_pos[1] + rel_y
        x = agent_pos[0] + rel_x
        if 0 <= y and y < len(lines) and 0 <= x and x < len(lines[0]):
            curr_map[size + rel_y][size + rel_x] = MAP_MAP[lines[y][x]]
# for l in curr_map:
#     print(l)
data.append(curr_map)

# %%
for kind, features in FEATURE_ENTITY_DICT.items():
    for feature in features:
        curr_map = [[0] * int(size * 2 + 1) for i in range(int(size * 2 + 1))]
        # curr_map[size][size] = 'A'
        for e in state:
            rel_x = max(min(e['rel_x'], size), -size)
            rel_y = max(min(e['rel_y'], size), -size)
            if abs(rel_x) <= size and abs(rel_y) <= size and e['kind'] == kind:
                curr_map[size + rel_y][size + rel_x] = e[feature]
        # print(kind, feature)
        # for l in curr_map:
        #     print(l)
        data.append(curr_map)

# %%
len(data)
# Out:
# 12

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

class SimpleConvNet(nn.Module):
    def __init__(self, in_channels=3, num_classes=5):
        super(SimpleConvNet, self).__init__()
        self.conv1 = nn.Conv2d(in_channels, 16, kernel_size=3, padding=1)
        self.conv2 = nn.Conv2d(16, 32, kernel_size=3, padding=1)
        self.pool = nn.MaxPool2d(2, 2)  # уменьшает размер в 2 раза
        self.fc1 = nn.Linear(32 * 5 * 5, 64)  # предполагаем вход размером 10x10
        self.fc2 = nn.Linear(64, num_classes)

    def forward(self, x):
        x = F.relu(self.conv1(x))  # [B, 16, H, W]
        x = self.pool(F.relu(self.conv2(x)))  # [B, 32, H/2, W/2]
        x = torch.flatten(x, 1)  # [B, 32*H/2*W/2]
        x = F.relu(self.fc1(x))
        x = self.fc2(x)
        return x

# %%
model = SimpleConvNet(12, 5)

# %%
inputs = torch.tensor([data], dtype=torch.float32)

# %%
model(inputs)
# Out:
# tensor([[-0.5285, -0.2132, -0.5920, -0.9146,  0.0792]],
#        grad_fn=<AddmmBackward0>)

# %%
EXTENDED_KUTULU_ACTIONS[episode.action]
# Out:
# 'RIGHT'

# %%
viz_observation(episode.observation, episode.action)
# Out:
# ###############
# #.............#
# #.#.#.#.#.#.#.#
# #..WW....W.w..#
# #.#.#.#.#.#.#.#
# #.........PR^.#
# #.#.#.#.#.#.#.#
# #.........1...#
# #.#.#.#.#.#.#.#
# #..w..R....w..#
# #.#.#.#.#.#.#.#
# #.............#
# ###############

# %%
EXTENDED_KUTULU_ACTIONS[episode.action]
# Out:
# 'RIGHT'

# %%
episode.reward
# Out:
# 0.1

# %%
print_exp(episode.state)
# Out:
# {'kind': 'EXPLORER', 'param0': 207, 'param1': 1, 'param2': 0, 'rel_x': -1, 'rel_y': 0, 'dist': 1, 'dir': (3,), 'raw_dist': 1, 'on_los': True}
# {'kind': 'EXPLORER', 'param0': 147, 'param1': 0, 'param2': 0, 'rel_x': -1, 'rel_y': 2, 'dist': 3, 'dir': (2,), 'raw_dist': 3, 'on_los': False}
# {'kind': 'SLASHER', 'param0': 1, 'param1': 4, 'param2': -1, 'rel_x': 1, 'rel_y': 0, 'dist': 1, 'dir': (1,), 'raw_dist': 1, 'on_los': True}
# {'kind': 'WANDERER', 'param0': 28, 'param1': 1, 'param2': 0, 'rel_x': -2, 'rel_y': -2, 'dist': 4, 'dir': (0, 3), 'raw_dist': 4, 'on_los': False}
# {'kind': 'SLASHER', 'param0': 4, 'param1': 0, 'param2': 2, 'rel_x': 0, 'rel_y': 0, 'dist': 0, 'dir': (4,), 'raw_dist': 0, 'on_los': True}
# {'kind': 'EFFECT_PLAN', 'param0': 4, 'param1': 0, 'param2': -1, 'rel_x': -1, 'rel_y': 0, 'dist': 1, 'dir': (3,), 'raw_dist': 1, 'on_los': True}
# .......
# .W.....
# .......
# ..PRR..
# .......
# ..E....
# .......

# %%
print_exp(episode.new_state)
# Out:
# {'kind': 'EXPLORER', 'param0': 205, 'param1': 1, 'param2': 0, 'rel_x': -3, 'rel_y': 0, 'dist': 3, 'dir': (3,), 'raw_dist': 3, 'on_los': True}
# {'kind': 'EXPLORER', 'param0': 142, 'param1': 0, 'param2': 0, 'rel_x': -1, 'rel_y': 2, 'dist': 3, 'dir': (3,), 'raw_dist': 3, 'on_los': False}
# {'kind': 'SLASHER', 'param0': 34, 'param1': 1, 'param2': -1, 'rel_x': 0, 'rel_y': 0, 'dist': 0, 'dir': (4,), 'raw_dist': 0, 'on_los': True}
# {'kind': 'WANDERER', 'param0': 27, 'param1': 1, 'param2': 0, 'rel_x': -3, 'rel_y': -1, 'dist': 4, 'dir': (3,), 'raw_dist': 4, 'on_los': False}
# {'kind': 'SLASHER', 'param0': 3, 'param1': 0, 'param2': 2, 'rel_x': -1, 'rel_y': 0, 'dist': 1, 'dir': (3,), 'raw_dist': 1, 'on_los': True}
# {'kind': 'EFFECT_PLAN', 'param0': 3, 'param1': 0, 'param2': -1, 'rel_x': -3, 'rel_y': 0, 'dist': 3, 'dir': (3,), 'raw_dist': 3, 'on_los': True}
# .......
# .......
# W......
# P.RR...
# .......
# ..E....
# .......

# %%
agents_dir = '../output/2025-05-28/20250528-122750'
agent_id = 0

# %%
checkpoint_dir = f'{agents_dir}/agent{agent_id}/5000'

# %%
with open(f'{agents_dir}/agents_info.json') as f:
    agents_info = json.load(f)
    info = agents_info[agent_id]
    del info['type']

# %%
agent = DQNAgentExt(**info)
agent.train = False

# %%
agent.model.load_state_dict(torch.load(f"{checkpoint_dir}/model.pt"))
# Out:
# <All keys matched successfully>

# %%
# agent = REINFORCEAgent(**{
#     'state_type': 'closest_ext',
#     'gamma': 0.5,
#     'action_space_n': 8,
#     'train': False,
# })

# %%
from src.envs.distance import find_path
from src.envs.kutulu_observer import KutuluClosestObserver, KutuluClosestExtObserver
from src.envs.kutulu_world import KutuluWorldEnv
from src.game.template import CELL_WALL, DEFAULT_KUTULU_ACTIONS, EXTENDED_KUTULU_ACTIONS
from src.game.template import MOVE_REL_POS, REL_POSITIONS

# %%
env = KutuluWorldEnv('', '', 1, actions=EXTENDED_KUTULU_ACTIONS)
env.map = [
    #0123456
    '#######', # 0
    '#.....#', # 1
    '#.#.#.#', # 2
    '#.....#', # 3
    '#.#.#.#', # 4
    '#.....#', # 5
    '#######', # 6
]
env.width = len(env.map[0])
env.height = len(env.map)

# %%
all_answers = set(range(4))
params = [
    (set([answer]), [rel_pos], [])
    for answer, rel_pos in enumerate(REL_POSITIONS[:-1])
] + [
    (set([answer]), [(tuple(x * 2 for x in rel_pos))], [])
    for answer, rel_pos in enumerate(REL_POSITIONS[:-1])
] + [
    (set([answer]), [(tuple(x * 3 for x in rel_pos))], [])
    for answer, rel_pos in enumerate(REL_POSITIONS[:-1])
] + [
    (all_answers - set([answer]), [], [rel_pos])
    for answer, rel_pos in enumerate(REL_POSITIONS[:-1])
] + [
    (all_answers - set([answer]), [], [tuple(x * 2 for x in rel_pos)])
    for answer, rel_pos in enumerate(REL_POSITIONS[:-1])
]

# %%
def set_env(agent, env, explorers, wanderers):
    player_id = 0
    player_pos = (3, 3)
    obs = [
        None,
        f'EXPLORER 0 {player_pos[0]} {player_pos[1]} 100 0 0'
    ] + [
        f'EXPLORER {i + 1} {player_pos[0] + x} {player_pos[1] + y} 10 0 0'
        for i, (x, y) in enumerate(explorers) 
    ] + [
        f'WANDERER {i + 10} {player_pos[0] + x} {player_pos[1] + y} 10 1 0'
        for i, (x, y) in enumerate(wanderers) 
    ]
    env._set_entities(obs)
    env._set_players(obs, set_ids=True)
    agent.set_env(env)

# %%
for answer, explorers, wanderers in params:
    set_env(agent, env, explorers, wanderers)
    state, action = agent.generate_state_and_step(0)
    print(action, answer, explorers, wanderers)
# Out:
# 0 {0} [(0, -1)] []
# 0 {1} [(1, 0)] []
# 0 {2} [(0, 1)] []
# 0 {3} [(-1, 0)] []
# 0 {0} [(0, -2)] []
# 2 {1} [(2, 0)] []
# 0 {2} [(0, 2)] []
# 2 {3} [(-2, 0)] []
# 0 {0} [(0, -3)] []
# 0 {1} [(3, 0)] []
# 0 {2} [(0, 3)] []
# 0 {3} [(-3, 0)] []
# 1 {1, 2, 3} [] [(0, -1)]
# 2 {0, 2, 3} [] [(1, 0)]
# 0 {0, 1, 3} [] [(0, 1)]
# 1 {0, 1, 2} [] [(-1, 0)]
# 1 {1, 2, 3} [] [(0, -2)]
# 2 {0, 2, 3} [] [(2, 0)]
# 0 {0, 1, 3} [] [(0, 2)]
# 2 {0, 1, 2} [] [(-2, 0)]

# %%
answer, explorers, wanderers = params[1]
set_env(agent, env, explorers, wanderers)
state, action = agent.generate_state_and_step(0)

# %%
action, answer, explorers, wanderers
# Out:
# (np.int64(0), {1}, [(1, 0)], [])

# %%
self = agent
player_id = 0

# %%
self.frame_idx += 1

valid_actions = self.get_valid_actions(player_id)
player_mask = ~np.array(valid_actions)
player_mask = player_mask[:self.action_space_n]

state = self.get_state(player_id)
data = self.episode_buffer.encode_states([state])

# %%
self = self.model

# %%
assert data['entity_dir'].shape[-1] == self.num_dirs

x_kind_embs = self.kind_embs(data['entity_kind'])

entity_features = data['entity_features']
x_features = self.features_linear(entity_features)

entity_dir = data['entity_dir']
x_dir = self.dir_linear(entity_dir)
entities_mask = (entity_dir > 0).max(dim=-1, keepdim=True)[0]

# [batch_size, entity_dim, embed_dim + hidden_dim + inner_dim]
x_entitity = torch.cat((x_kind_embs, x_features, x_dir), dim=-1)
# [batch_size, entity_dim, inner_dim]
x = self.entity_linear(x_entitity)

# entity_weights = self.entity_impact(x_entitity) * entities_mask
entity_weights = torch.softmax(self.entity_impact(x_entitity), dim=-1) * entities_mask
# [batch_size, inner_dim, entity_dim]
x_transposed = x.transpose(1, 2)
# [batch_size, inner_dim, num_classes]
x = torch.bmm(x_transposed, entity_weights)
# [batch_size, num_classes, inner_dim]
x = x.transpose(2, 1)
# [batch_size, num_classes]
output = self.out_linear(x.reshape(-1, self.num_classes * self.inner_dim))

# %%
output
# Out:
# tensor([[ 0.0073,  0.0061,  0.0068,  0.0057,  0.0641,  0.0180,  0.0106, -0.0343]],
#        grad_fn=<AddmmBackward0>)

# %%
x_entitity
# Out:
# tensor([[[-0.6977, -2.1059, -0.1461,  ...,  0.5730,  0.0271, -0.1460],
#          [ 1.5836,  0.2096,  1.6686,  ...,  0.2610,  0.1146, -0.1244],
#          [ 1.5836,  0.2096,  1.6686,  ...,  0.2610,  0.1146, -0.1244],
#          ...,
#          [ 1.5836,  0.2096,  1.6686,  ...,  0.2610,  0.1146, -0.1244],
#          [ 1.5836,  0.2096,  1.6686,  ...,  0.2610,  0.1146, -0.1244],
#          [ 1.5836,  0.2096,  1.6686,  ...,  0.2610,  0.1146, -0.1244]]],
#        grad_fn=<CatBackward0>)

# %%
self.entity_impact(x_entitity)
# Out:
# tensor([[[  1.8449, -10.8001,  -0.9138,   1.8049,  -2.2458,   1.1164,   2.8130,
#             1.5953],
#          [ -0.3742,  -0.0887,  -0.5627,  -0.2143,  -0.4218,  -0.2570,  -0.1607,
#            -0.4728],
#          [ -0.3742,  -0.0887,  -0.5627,  -0.2143,  -0.4218,  -0.2570,  -0.1607,
#            -0.4728],
#          [ -0.3742,  -0.0887,  -0.5627,  -0.2143,  -0.4218,  -0.2570,  -0.1607,
#            -0.4728],
#          [ -0.3742,  -0.0887,  -0.5627,  -0.2143,  -0.4218,  -0.2570,  -0.1607,
#            -0.4728],
#          [ -0.3742,  -0.0887,  -0.5627,  -0.2143,  -0.4218,  -0.2570,  -0.1607,
#            -0.4728],
#          [ -0.3742,  -0.0887,  -0.5627,  -0.2143,  -0.4218,  -0.2570,  -0.1607,
#            -0.4728],
#          [ -0.3742,  -0.0887,  -0.5627,  -0.2143,  -0.4218,  -0.2570,  -0.1607,
#            -0.4728],
#          [ -0.3742,  -0.0887,  -0.5627,  -0.2143,  -0.4218,  -0.2570,  -0.1607,
#            -0.4728],
#          [ -0.3742,  -0.0887,  -0.5627,  -0.2143,  -0.4218,  -0.2570,  -0.1607,
#            -0.4728],
#          [ -0.3742,  -0.0887,  -0.5627,  -0.2143,  -0.4218,  -0.2570,  -0.1607,
#            -0.4728],
#          [ -0.3742,  -0.0887,  -0.5627,  -0.2143,  -0.4218,  -0.2570,  -0.1607,
#            -0.4728],
#          [ -0.3742,  -0.0887,  -0.5627,  -0.2143,  -0.4218,  -0.2570,  -0.1607,
#            -0.4728],
#          [ -0.3742,  -0.0887,  -0.5627,  -0.2143,  -0.4218,  -0.2570,  -0.1607,
#            -0.4728],
#          [ -0.3742,  -0.0887,  -0.5627,  -0.2143,  -0.4218,  -0.2570,  -0.1607,
#            -0.4728],
#          [ -0.3742,  -0.0887,  -0.5627,  -0.2143,  -0.4218,  -0.2570,  -0.1607,
#            -0.4728],
#          [ -0.3742,  -0.0887,  -0.5627,  -0.2143,  -0.4218,  -0.2570,  -0.1607,
#            -0.4728],
#          [ -0.3742,  -0.0887,  -0.5627,  -0.2143,  -0.4218,  -0.2570,  -0.1607,
#            -0.4728],
#          [ -0.3742,  -0.0887,  -0.5627,  -0.2143,  -0.4218,  -0.2570,  -0.1607,
#            -0.4728],
#          [ -0.3742,  -0.0887,  -0.5627,  -0.2143,  -0.4218,  -0.2570,  -0.1607,
#            -0.4728]]], grad_fn=<ViewBackward0>)

# %%
entity_weights
# Out:
# tensor([[[1.6847e-01, 5.4308e-07, 1.0676e-02, 1.6187e-01, 2.8181e-03,
#           8.1308e-02, 4.4360e-01, 1.3127e-01],
#          [0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#           0.0000e+00, 0.0000e+00, 0.0000e+00],
#          [0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#           0.0000e+00, 0.0000e+00, 0.0000e+00],
#          [0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#           0.0000e+00, 0.0000e+00, 0.0000e+00],
#          [0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#           0.0000e+00, 0.0000e+00, 0.0000e+00],
#          [0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#           0.0000e+00, 0.0000e+00, 0.0000e+00],
#          [0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#           0.0000e+00, 0.0000e+00, 0.0000e+00],
#          [0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#           0.0000e+00, 0.0000e+00, 0.0000e+00],
#          [0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#           0.0000e+00, 0.0000e+00, 0.0000e+00],
#          [0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#           0.0000e+00, 0.0000e+00, 0.0000e+00],
#          [0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#           0.0000e+00, 0.0000e+00, 0.0000e+00],
#          [0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#           0.0000e+00, 0.0000e+00, 0.0000e+00],
#          [0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#           0.0000e+00, 0.0000e+00, 0.0000e+00],
#          [0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#           0.0000e+00, 0.0000e+00, 0.0000e+00],
#          [0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#           0.0000e+00, 0.0000e+00, 0.0000e+00],
#          [0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#           0.0000e+00, 0.0000e+00, 0.0000e+00],
#          [0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#           0.0000e+00, 0.0000e+00, 0.0000e+00],
#          [0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#           0.0000e+00, 0.0000e+00, 0.0000e+00],
#          [0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#           0.0000e+00, 0.0000e+00, 0.0000e+00],
#          [0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#           0.0000e+00, 0.0000e+00, 0.0000e+00]]], grad_fn=<MulBackward0>)

# %%
model_output = output[0].detach().cpu().numpy()

# %%
actions_masked = np.ma.array(model_output, mask=player_mask)

# %%
actions_masked
# Out:
# masked_array(data=[0.0031038778834044933, 0.0053454115986824036,
#                    0.0010488568805158138, 0.0024201711639761925, --, --,
#                    --, --],
#              mask=[False, False, False, False,  True,  True,  True,  True],
#        fill_value=np.float64(1e+20),
#             dtype=float32)

# %%
self.train
# Out:
# <bound method Module.train of DQNExt(
#   (kind_embs): Embedding(13, 32)
#   (features_linear): Linear(in_features=7, out_features=32, bias=True)
#   (dir_linear): Linear(in_features=5, out_features=16, bias=True)
#   (entity_linear): Linear(in_features=80, out_features=16, bias=True)
#   (entity_impact): Linear(in_features=80, out_features=8, bias=True)
#   (out_linear): Linear(in_features=128, out_features=8, bias=True)
# )>

# %%
action = actions_masked.argmax()

# %%
action
# Out:
# np.int64(1)

# %%
import torch
import torch.nn as nn
out_linear = nn.Linear(16 * 8, 8)

# %%
out_linear(x.reshape(-1, 16 * 8))
# Out:
# tensor([[-0.0682,  0.0097,  0.0179, -0.1315,  0.0023, -0.1417,  0.0012, -0.0833]],
#        grad_fn=<AddmmBackward0>)

# %%
16 * 8 * 8
# Out:
# 1024

# %%
# [batch_size, num_classes]
output = self.out_linear(x).squeeze(-1)

# %%
output
# Out:
# tensor([[13.3777, 11.4812,  9.7850, 13.0480, -1.5532,  3.6007,  6.6069, -2.4162]],
#        grad_fn=<SqueezeBackward1>)

# %%
output
# Out:
# tensor([[12.6539, 10.6024,  8.9396, 12.1601, -1.5361,  3.0114,  6.0064, -2.9908]],
#        grad_fn=<SqueezeBackward1>)

# %%
set_env(agent, env, [(0, -2)], [])

# %%
self = agent

# %%
player_id = 0

# %%
valid_actions = self.get_valid_actions(player_id)
player_mask = ~np.array(valid_actions)
player_mask = player_mask[:self.action_space_n]


state = self.get_state(player_id)
data = self.episode_buffer.encode_states([state])
model_output = self.model(data)[0].detach().cpu().numpy()
actions_masked = np.ma.array(model_output, mask=player_mask)

# %%
model_output.std()
# Out:
# np.float32(0.04868661)

# %%
model_output
# Out:
# array([-0.31248164, -0.23298003, -0.32872823, -0.21628943], dtype=float32)

# %%
actions_masked.std()
# Out:
# np.float64(0.04868661068708801)

# %%
(actions_masked / actions_masked.sum()).std()
# Out:
# np.float64(0.0446469902019552)
